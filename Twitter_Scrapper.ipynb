# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiran00098/guvicodes/blob/main/Twitter_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-n2mjtdtm
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-n2mjtdtm
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit b515a66b937276eafff41cf6b897c53ecf3d54a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for UNKNOWN: filename=UNKNOWN-0.5.0.20230114.dev6+gb515a66-py3-none-any.whl size=13550 sha256=8490a48303db94bb28cd14b0696f8f4f48a376ef81aa363d07b701a95cbf50b0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mx3wxytl/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built UNKNOWN
# ...

# %%
import os
import pandas as pd

# %%
tweet_count = 1000
text_query = input()
since_date = "2022-09-01"
until_date = "2023-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df2.head()

# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
# Out:
# coke

# %%
tweets_df2.columns
tweets_df2.drop(['_type','rawContent','renderedContent','quoteCount','conversationId','source', 'sourceUrl', 'sourceLabel', 'links', 'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId','inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags','cashtags', 'card', 'viewCount', 'vibe'],axis =1)
# Out:
#                                                    url  \
# 0    https://twitter.com/Z_Unit_Delt_Sig/status/160...
# 1    https://twitter.com/Keemo3030/status/160933853...
# 2    https://twitter.com/TDN_Rhombus_WNI/status/160...
# 3    https://twitter.com/igotwhitet0es/status/16093...
# 4    https://twitter.com/SciRocker/status/160933841...
# ..                                                 ...
# 995  https://twitter.com/ThyroidCB/status/160929905...
# 996  https://twitter.com/buttersourness/status/1609...
# 997  https://twitter.com/MikeBianco6/status/1609298...
# 998  https://twitter.com/Reesetapher/status/1609298...
# 999  https://twitter.com/OfficielKaybaye/status/160...
#
#                          date                   id  \
# 0   2022-12-31 23:59:57+00:00  1609338601619488770
# 1   2022-12-31 23:59:40+00:00  1609338532354457602
# 2   2022-12-31 23:59:29+00:00  1609338483231055872
# 3   2022-12-31 23:59:24+00:00  1609338464410935296
# ...

# %%
pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 51.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 25.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 KB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 85.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 9.9 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
